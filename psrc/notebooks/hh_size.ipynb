# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

# %%
cwd = os.getcwd()
data_path = os.path.join(os.path.dirname(cwd), 'output', 'summary_block_group_id.csv')  
df = pd.read_csv(data_path)

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_1_result'], df['hh_size_1_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 1')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_2_result'], df['hh_size_2_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 2')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_3_result'], df['hh_size_3_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 3')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_4_result'], df['hh_size_4_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 4')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_5_result'], df['hh_size_5_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 5')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_6_result'], df['hh_size_6_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 6')
plt.xlabel('result')
plt.ylabel('control')
plt.show()

# %%
# Plot
colors = (0,0,0)
area = np.pi*2

plt.figure(figsize=(6, 6))
plt.scatter(df['hh_size_7_plus_result'], df['hh_size_7_plus_control'], s=area, c=colors, alpha=1)
plt.title('HH Size 7')
plt.xlabel('result')
plt.ylabel('control')
plt.show()
