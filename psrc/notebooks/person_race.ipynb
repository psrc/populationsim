# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

# %%
cwd = os.getcwd()
data_path = os.path.join(os.path.dirname(cwd), 'output', 'final_summary_block_group_id.csv')  
df = pd.read_csv(data_path)

# %% [markdown]
# # Male

# %%
field = 'white'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Female

# %%
field = 'female'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Race

# %%
field = 'black'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %%
field = 'white'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %%
field = 'other'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')
