# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import os

# %matplotlib inline

pd.options.display.float_format = '{:0,.0f}'.format

# %%
cwd = os.getcwd()
data_path = os.path.join(os.path.dirname(cwd), 'output', 'summary_adjusted.csv')  
df = pd.read_csv(data_path)

# %%
def plot_chart(df, field_list, xfield='_control', yfield='_adjusted'):
    for field in field_list:
        ax = df.plot(kind='scatter', x=field+xfield, y=field+yfield)
        lim = df[[field+xfield,field+yfield]].max().max()*1.05
        ax.set_ylim(0,lim)
        ax.set_xlim(0,lim)
        x = np.linspace(*ax.get_xlim())
        ax.plot(x, x)
        slope, intercept, r_value, p_value, std_err = stats.linregress(df[field+xfield],df[field+yfield])
        print('r^2 ' + str(field) + ': ' + str(r_value))
        
        
    sum_df = pd.DataFrame()
    for source in ['control','adjusted','result']:
        df[field+'_'+source] = df[field+'_'+source].astype('float')
        sum_df[source] = df[[field+'_'+source for field in field_list]].sum().values
    sum_df.index = field_list
    display(sum_df)

# %% [markdown]
# # HH Size and Populations
# ## Initial Result
# -----

# %%
plot_chart(df, field_list=['num_persons','num_hh'], xfield='_control', yfield='_result')
# Out:
# r^2 num_persons: 0.9961888912733576
# r^2 num_hh: 1.0
#               control  adjusted    result
# num_persons 4,053,346 4,048,896 3,993,435
# num_hh      1,605,264 1,605,264 1,605,264

# %% [markdown]
# ## Adjusted
# -----

# %%
plot_chart(df, field_list=['num_persons','num_hh'], xfield='_control', yfield='_adjusted')
# Out:
# r^2 num_persons: 0.9976178489364405
# r^2 num_hh: 1.0
#               control  adjusted    result
# num_persons 4,053,346 4,048,896 3,993,435
# num_hh      1,605,264 1,605,264 1,605,264

# %% [markdown]
# # School
# ## Initial Result
# -----

# %%
plot_chart(df, field_list=['school_yes','school_no'], xfield='_control', yfield='_result')
# Out:
# r^2 school_yes: 0.9805733706501175
# r^2 school_no: 0.9924116665597023
#              control  adjusted    result
# school_yes   936,983   952,759   932,836
# school_no  3,116,347 3,096,137 3,060,599

# %% [markdown]
# ## Adjusted
# -----

# %%
plot_chart(df, field_list=['school_yes','school_no'], xfield='_control', yfield='_adjusted')
# Out:
# r^2 school_yes: 0.9801157922888356
# r^2 school_no: 0.9940453835577194
#              control  adjusted    result
# school_yes   936,983   952,759   932,836
# school_no  3,116,347 3,096,137 3,060,599

# %% [markdown]
# # Age
# ## Initial Results
# ----

# %%
plot_chart(df, field_list=['age_19_and_under','age_20_to_35','age_35_to_60','age_above_60'],
          xfield='_control', yfield='_result')
# Out:
# r^2 age_19_and_under: 0.9949674778767476
# r^2 age_20_to_35: 0.9950040765012068
# r^2 age_35_to_60: 0.9916266365488013
# r^2 age_above_60: 0.9940405166837092
#                    control  adjusted    result
# age_19_and_under   949,864   958,131   936,109
# age_20_to_35       916,457   909,675   901,990
# age_35_to_60     1,397,982 1,387,452 1,377,301
# age_above_60       789,038   793,638   778,035

# %% [markdown]
# ## Adjusted
# -----

# %%
plot_chart(df, field_list=['age_19_and_under','age_20_to_35','age_35_to_60','age_above_60'],
          xfield='_control', yfield='_adjusted')
# Out:
# r^2 age_19_and_under: 0.9943210575170137
# r^2 age_20_to_35: 0.9955153839500082
# r^2 age_35_to_60: 0.992875314058957
# r^2 age_above_60: 0.995965887457363
#                    control  adjusted    result
# age_19_and_under   949,864   958,131   936,109
# age_20_to_35       916,457   909,675   901,990
# age_35_to_60     1,397,982 1,387,452 1,377,301
# age_above_60       789,038   793,638   778,035

# %% [markdown]
# # Income
# ## Initial Results
# ----

# %%
plot_chart(df, field_list=['income_lt15','income_gt15-lt30','income_gt30-lt60','income_gt60-lt100','income_gt100'],
          xfield='_control', yfield='_result')
# Out:
# r^2 income_lt15: 0.9994760251847078
# r^2 income_gt15-lt30: 0.9998726578179262
# r^2 income_gt30-lt60: 0.9999389741993726
# r^2 income_gt60-lt100: 0.9999132450421139
# r^2 income_gt100: 0.9999593253293787
#                    control  adjusted  result
# income_lt15        117,891   117,820 117,820
# income_gt15-lt30   143,944   143,847 143,847
# income_gt30-lt60   327,344   327,375 327,375
# income_gt60-lt100  370,319   370,422 370,422
# income_gt100       645,688   645,800 645,800

# %% [markdown]
# ## Adjusted
# ----

# %%
plot_chart(df, field_list=['income_lt15','income_gt15-lt30','income_gt30-lt60','income_gt60-lt100','income_gt100'],
          xfield='_control', yfield='_adjusted')
# Out:
# r^2 income_lt15: 0.9994760251847078
# r^2 income_gt15-lt30: 0.9998726578179262
# r^2 income_gt30-lt60: 0.9999389741993726
# r^2 income_gt60-lt100: 0.9999132450421139
# r^2 income_gt100: 0.9999593253293787
#                    control  adjusted  result
# income_lt15        117,891   117,820 117,820
# income_gt15-lt30   143,944   143,847 143,847
# income_gt30-lt60   327,344   327,375 327,375
# income_gt60-lt100  370,319   370,422 370,422
# income_gt100       645,688   645,800 645,800

# %% [markdown]
# # Workers
# ## Initial Results
# ----

# %%
plot_chart(df, field_list=['workers_0','workers_1','workers_2','workers_3_plus'],
          xfield='_control', yfield='_result')
# Out:
# r^2 workers_0: 0.9912433375539161
# r^2 workers_1: 0.9987232034307442
# r^2 workers_2: 0.9981399049178513
# r^2 workers_3_plus: 0.9952616543218704
#                 control  adjusted  result
# workers_0       347,020   356,988 356,988
# workers_1       635,036   629,395 629,395
# workers_2       512,027   508,291 508,291
# workers_3_plus  111,104   110,590 110,590

# %% [markdown]
# ## Adjusted
# ----

# %%
plot_chart(df, field_list=['workers_0','workers_1','workers_2','workers_3_plus'],
          xfield='_control', yfield='_adjusted')
# Out:
# r^2 workers_0: 0.9912433375539161
# r^2 workers_1: 0.9987232034307442
# r^2 workers_2: 0.9981399049178513
# r^2 workers_3_plus: 0.9952616543218704
#                 control  adjusted  result
# workers_0       347,020   356,988 356,988
# workers_1       635,036   629,395 629,395
# workers_2       512,027   508,291 508,291
# workers_3_plus  111,104   110,590 110,590

# %% [markdown]
# # Household Size
# ## Initial Result
# ----

# %%
plot_chart(df, field_list=['hh_size_1','hh_size_2','hh_size_3','hh_size_4','hh_size_5','hh_size_6','hh_size_7_plus'],
          xfield='_control', yfield='_result')
# Out:
# r^2 hh_size_1: 0.9976805539609984
# r^2 hh_size_2: 0.9956237543843075
# r^2 hh_size_3: 0.9955176395135651
# r^2 hh_size_4: 0.9977515972143904
# r^2 hh_size_5: 0.9964690621652789
# r^2 hh_size_6: 0.9945651119656932
# r^2 hh_size_7_plus: 0.9909903936746133
#                 control  adjusted  result
# hh_size_1       463,066   454,017 454,017
# hh_size_2       534,271   535,077 535,077
# hh_size_3       251,862   254,756 254,756
# hh_size_4       210,397   213,603 213,603
# hh_size_5        87,255    88,923  88,923
# hh_size_6        34,248    34,889  34,889
# hh_size_7_plus   23,804    23,999  23,999

# %% [markdown]
# ## Adjusted
# ----

# %%
plot_chart(df, field_list=['hh_size_1','hh_size_2','hh_size_3','hh_size_4','hh_size_5','hh_size_6','hh_size_7_plus'],
          xfield='_control', yfield='_adjusted')
# Out:
# r^2 hh_size_1: 0.9976805539609984
# r^2 hh_size_2: 0.9956237543843075
# r^2 hh_size_3: 0.9955176395135651
# r^2 hh_size_4: 0.9977515972143904
# r^2 hh_size_5: 0.9964690621652789
# r^2 hh_size_6: 0.9945651119656932
# r^2 hh_size_7_plus: 0.9909903936746133
#                 control  adjusted  result
# hh_size_1       463,066   454,017 454,017
# hh_size_2       534,271   535,077 535,077
# hh_size_3       251,862   254,756 254,756
# hh_size_4       210,397   213,603 213,603
# hh_size_5        87,255    88,923  88,923
# hh_size_6        34,248    34,889  34,889
# hh_size_7_plus   23,804    23,999  23,999

# %% [markdown]
# # Worker Total
# ## Initial Result
# ----

# %%
plot_chart(df, field_list=['is_worker'], xfield='_control', yfield='_result')
# Out:
# r^2 is_worker: 0.9766673206186813
#             control  adjusted    result
# is_worker 1,944,883 2,018,584 2,018,584

# %% [markdown]
# ## Adjusted
# ----

# %%
plot_chart(df, field_list=['is_worker'], xfield='_control', yfield='_adjusted')
# Out:
# r^2 is_worker: 0.9766673206186813
#             control  adjusted    result
# is_worker 1,944,883 2,018,584 2,018,584

# %% [markdown]
# # Family

# %%
plot_chart(df, field_list=['is_family','not_family'])
# Out:
# r^2 is_family: 0.9980155148597966
# r^2 not_family: 0.9987250829880823
#              control  adjusted    result
# is_family  1,015,781 1,017,566 1,017,566
# not_family   589,441   587,698   587,698

# %% [markdown]
# # Gender

# %%
plot_chart(df, field_list=['male','female'], xfield='_control', yfield='_result')
# Out:
# r^2 male: 0.9920761118101149
# r^2 female: 0.992519145810787
#          control  adjusted    result
# male   2,025,802 2,020,245 1,994,553
# female 2,027,575 2,028,651 1,998,882

# %%
plot_chart(df, field_list=['male','female'], xfield='_control', yfield='_adjusted')
# Out:
# r^2 male: 0.9934240338281652
# r^2 female: 0.9934742372807944
#          control  adjusted    result
# male   2,025,802 2,020,245 1,994,553
# female 2,027,575 2,028,651 1,998,882

# %% [markdown]
# # Cars

# %%
plot_chart(df, field_list=['cars_none','cars_one','cars_two_or_more'], xfield='_control', yfield='_result')
# Out:
# r^2 cars_none: 0.9991838404245802
# r^2 cars_one: 0.9991141577265211
# r^2 cars_two_or_more: 0.9990874326298044
#                   control  adjusted  result
# cars_none         129,112   127,313 127,313
# cars_one          504,743   500,566 500,566
# cars_two_or_more  971,350   977,385 964,802

# %%
plot_chart(df, field_list=['cars_none','cars_one','cars_two_or_more'], xfield='_control', yfield='_adjusted')
# Out:
# r^2 cars_none: 0.9991838404245802
# r^2 cars_one: 0.9991141577265211
# r^2 cars_two_or_more: 0.9970845024013903
#                   control  adjusted  result
# cars_none         129,112   127,313 127,313
# cars_one          504,743   500,566 500,566
# cars_two_or_more  971,350   977,385 964,802

# %% [markdown]
# # CrossTabs

# %%
# Across household size and income

field_list_x =['income_lt15','income_gt15-lt30','income_gt30-lt60','income_gt60-lt100','income_gt100']
field_list_y = ['hh_size_1','hh_size_2','hh_size_3','hh_size_4','hh_size_5','hh_size_6','hh_size_7_plus']

_df = df.copy()
field_list = []
for source in ['_control','_adjusted']:
    for x in field_list_x:
        for y in field_list_y:
            _df[x+'_'+y+source] = _df[x+source]+_df[y+source]
    
        
            field_list.append(x+'_'+y)

# %%
plot_chart(_df, field_list=field_list)
# Out:
# r^2 income_lt15_hh_size_1: 0.9983836018954545
# r^2 income_lt15_hh_size_2: 0.9975441697026323
# r^2 income_lt15_hh_size_3: 0.9979510373281868
# r^2 income_lt15_hh_size_4: 0.998528806198017
# r^2 income_lt15_hh_size_5: 0.99903934523283
# r^2 income_lt15_hh_size_6: 0.9993187065117084
# r^2 income_lt15_hh_size_7_plus: 0.9992929609034851
# r^2 income_gt15-lt30_hh_size_1: 0.9983330752417386
# r^2 income_gt15-lt30_hh_size_2: 0.9974440573737837
# r^2 income_gt15-lt30_hh_size_3: 0.9982695017708567
# r^2 income_gt15-lt30_hh_size_4: 0.9988668392735365
# r^2 income_gt15-lt30_hh_size_5: 0.9993945395557796
# r^2 income_gt15-lt30_hh_size_6: 0.9996916231779132
# r^2 income_gt15-lt30_hh_size_7_plus: 0.9996363969212179
# r^2 income_gt30-lt60_hh_size_1: 0.998659359459613
# r^2 income_gt30-lt60_hh_size_2: 0.9983986645772501
# r^2 income_gt30-lt60_hh_size_3: 0.9992671361315869
# r^2 income_gt30-lt60_hh_size_4: 0.9994813697686281
# r^2 income_gt30-lt60_hh_size_5: 0.9997463679521881
# r^2 income_gt30-lt60_hh_size_6: 0.9998646103984784
# r^2 income_gt30-lt60_hh_size_7_plus: 0.9998438289576945
# r^2 income_gt60-lt100_hh_size_1: 0.9985958288908576
# r^2 income_gt60-lt100_hh_size_2: 0.9984723274869739
# r^2 income_gt60-lt100_hh_size_3: 0.9993917987965747
# r^2 income_gt60-lt100_hh_size_4: 0.9995613996530371
# r^2 income_gt60-lt100_hh_size_5: 0.9997711595371865
# r^2 income_gt60-lt100_hh_size_6: 0.999871530886855
# r^2 income_gt60-lt100_hh_size_7_plus: 0.9998536693700864
# r^2 income_gt100_hh_size_1: 0.9991516947464791
# r^2 income_gt100_hh_size_2: 0.9993281181055554
# r^2 income_gt100_hh_size_3: 0.9997901396750334
# r^2 income_gt100_hh_size_4: 0.9998645040628465
# r^2 income_gt100_hh_size_5: 0.9999233453459645
# r^2 income_gt100_hh_size_6: 0.9999482624382052
# r^2 income_gt100_hh_size_7_plus: 0.9999455072086956
# r^2 income_lt15_hh_size_1: 0.9983836018954545
# r^2 income_lt15_hh_size_2: 0.9975441697026323
# r^2 income_lt15_hh_size_3: 0.9979510373281868
# r^2 income_lt15_hh_size_4: 0.998528806198017
# r^2 income_lt15_hh_size_5: 0.99903934523283
# r^2 income_lt15_hh_size_6: 0.9993187065117084
# r^2 income_lt15_hh_size_7_plus: 0.9992929609034851
# r^2 income_gt15-lt30_hh_size_1: 0.9983330752417386
# r^2 income_gt15-lt30_hh_size_2: 0.9974440573737837
# r^2 income_gt15-lt30_hh_size_3: 0.9982695017708567
# r^2 income_gt15-lt30_hh_size_4: 0.9988668392735365
# r^2 income_gt15-lt30_hh_size_5: 0.9993945395557796
# r^2 income_gt15-lt30_hh_size_6: 0.9996916231779132
# r^2 income_gt15-lt30_hh_size_7_plus: 0.9996363969212179
# r^2 income_gt30-lt60_hh_size_1: 0.998659359459613
# r^2 income_gt30-lt60_hh_size_2: 0.9983986645772501
# r^2 income_gt30-lt60_hh_size_3: 0.9992671361315869
# r^2 income_gt30-lt60_hh_size_4: 0.9994813697686281
# r^2 income_gt30-lt60_hh_size_5: 0.9997463679521881
# r^2 income_gt30-lt60_hh_size_6: 0.9998646103984784
# r^2 income_gt30-lt60_hh_size_7_plus: 0.9998438289576945
# r^2 income_gt60-lt100_hh_size_1: 0.9985958288908576
# r^2 income_gt60-lt100_hh_size_2: 0.9984723274869739
# r^2 income_gt60-lt100_hh_size_3: 0.9993917987965747
# r^2 income_gt60-lt100_hh_size_4: 0.9995613996530371
# r^2 income_gt60-lt100_hh_size_5: 0.9997711595371865
# r^2 income_gt60-lt100_hh_size_6: 0.999871530886855
# r^2 income_gt60-lt100_hh_size_7_plus: 0.9998536693700864
# r^2 income_gt100_hh_size_1: 0.9991516947464791
# r^2 income_gt100_hh_size_2: 0.9993281181055554
# r^2 income_gt100_hh_size_3: 0.9997901396750334
# r^2 income_gt100_hh_size_4: 0.9998645040628465
# r^2 income_gt100_hh_size_5: 0.9999233453459645
# r^2 income_gt100_hh_size_6: 0.9999482624382052
# r^2 income_gt100_hh_size_7_plus: 0.9999455072086956
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda2\envs\test_python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'income_gt100_hh_size_7_plus_result'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-7fffc76cd5df> in <module>
# ----> 1 plot_chart(_df, field_list=field_list)
#
# <ipython-input-27-a5b7de0dabdc> in plot_chart(df, field_list, xfield, yfield)
#      13     sum_df = pd.DataFrame()
#      14     for source in ['control','adjusted','result']:
# ---> 15         df[field+'_'+source] = df[field+'_'+source].astype('float')
#      16         sum_df[source] = df[[field+'_'+source for field in field_list]].sum().values
#      17     sum_df.index = field_list
#
# C:\Anaconda2\envs\test_python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda2\envs\test_python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'income_gt100_hh_size_7_plus_result'

# %%
field_list

# %%
field_list
