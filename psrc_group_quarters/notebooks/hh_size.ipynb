# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

# %%
cwd = os.getcwd()
data_path = os.path.join(os.path.dirname(cwd), 'output', 'summary_block_group_id.csv')  
df = pd.read_csv(data_path)

# %% [markdown]
# # Household Size 1

# %%
field = 'hh_size_1'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 2

# %%
field = 'hh_size_2'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 3

# %%
field = 'hh_size_3'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 4

# %%
field = 'hh_size_4'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 5

# %%
field = 'hh_size_5'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 6

# %%
field = 'hh_size_6'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')

# %% [markdown]
# # Household Size 7 or More

# %%
field = 'hh_size_7_plus'
df.plot(kind='scatter', x=field+'_control', y=field+'_result')
